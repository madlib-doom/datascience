# %%
import pandas

data=pandas.read_csv("datasets/bank.csv")
data
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No      Graduate            No             5849
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# ..        ...     ...     ...           ...           ...              ...
# 609  LP002978  Female      No      Graduate            No             2900
# 610  LP002979    Male     Yes      Graduate            No             4106
# 611  LP002983    Male     Yes      Graduate            No             8072
# 612  LP002984    Male     Yes      Graduate            No             7583
# 613  LP002990  Female      No      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount Property_Area Loan_Status
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  592.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   85.587325
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.000000
# 50%        3812.500000        1188.500000  128.000000
# 75%        5795.000000        2297.250000  168.000000
# max       81000.000000       41667.000000  700.000000

# %%
data.groupby(["Property_Area","Loan_Status"]).size()
# Out:
# Property_Area  Loan_Status
# Rural          N               69
#                Y              110
# Semiurban      N               54
#                Y              179
# Urban          N               69
#                Y              133
# dtype: int64

# %%
data.groupby(["Gender","Married"]).size()
# Out:
# Gender  Married
# Female  No          83
#         Yes         42
# Male    No         130
#         Yes        359
# dtype: int64

# %%
data["Education"].value_counts().plot.pie(autopct="%1f%%")
# Out:
# <AxesSubplot: ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Property_Area",data=data,palette="winter",hue="Gender")
plt.title("Distribution of property between male and female")
# Out:
# Text(0.5, 1.0, 'Distribution of property between male and female')

# %%
sns.countplot(x="Education",data=data,palette="Oranges",hue="Property_Area")
# Out:
# <AxesSubplot: xlabel='Education', ylabel='count'>

# %%
sns.barplot(x="Education",y="ApplicantIncome",data=data,palette="summer",hue="Loan_Status")
# Out:
# <AxesSubplot: xlabel='Education', ylabel='ApplicantIncome'>

# %%
sns.barplot(x="Self_Employed",y="LoanAmount",data=data,palette="autumn")
# Out:
# /tmp/ipykernel_3518/271227159.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Self_Employed",y="LoanAmount",data=data,palette="autumn")
# <AxesSubplot: xlabel='Self_Employed', ylabel='LoanAmount'>

# %%
data.groupby(["Loan_ID","Gender"]).size()
# Out:
# Loan_ID   Gender
# LP001002  Male      1
# LP001003  Male      1
# LP001005  Male      1
# LP001006  Male      1
# LP001008  Male      1
#                    ..
# LP002978  Female    1
# LP002979  Male      1
# LP002983  Male      1
# LP002984  Male      1
# LP002990  Female    1
# Length: 614, dtype: int64

# %%
data["Property_Area"].value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <AxesSubplot: ylabel='count'>

# %%
data["ApplicantIncome"]
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
sns.swarmplot(x="Education",y="ApplicantIncome",data=data,palette="spring",hue="Property_Area")
# Out:
# /usr/lib/python3/dist-packages/seaborn/categorical.py:3399: UserWarning: 41.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/lib/python3/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='Education', ylabel='ApplicantIncome'>
# /usr/lib/python3/dist-packages/seaborn/categorical.py:3399: UserWarning: 56.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/lib/python3/dist-packages/seaborn/categorical.py:3399: UserWarning: 39.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.scatterplot(x="ApplicantIncome",y="LoanAmount",data=data,palette="spring",hue="Property_Area")
# Out:
# <AxesSubplot: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
import matplotlib.dates as mdates

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%b"))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())

sns.lineplot(x="Gender",y="ApplicantIncome",data=data,palette="spring")
# Out:
# /tmp/ipykernel_3518/1324260639.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x="Gender",y="ApplicantIncome",data=data,palette="spring")
# <AxesSubplot: xlabel='Gender', ylabel='ApplicantIncome'>

# %%
married_counts=data["Married"].value_counts()

plt.figure(figsize=(6,6))
wedges,texts,autotexts=plt.pie(
    married_counts,
    labels=married_counts.index,
    autopct="%1.1f%%",
    startangle=90,
    wedgeprops={'width':0.4}

)
centre_circle=plt.Circle((0,0),0.70,fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title("Distribution of Married people",fontsize=14)
plt.tight_layout()
plt.show()
