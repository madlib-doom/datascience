# %%
import pandas
data=pandas.read_csv("datasets/playstation.csv")
data
# Out:
#                                 Game Console                        Name  \
# 0             PS3_Grand Theft Auto V     PS3          Grand Theft Auto V
# 1             PS4_Grand Theft Auto V     PS4          Grand Theft Auto V
# 2      PS4_Call of Duty: Black Ops 3     PS4   Call of Duty: Black Ops 3
# 3          PS4_Red Dead Redemption 2     PS4       Red Dead Redemption 2
# 4     PS3_Call of Duty: Black Ops II     PS3  Call of Duty: Black Ops II
# ...                              ...     ...                         ...
# 4958    PS4_Chicory: A Colorful Tale     PS4    Chicory: A Colorful Tale
# 4959           PS4_Children of Morta     PS4           Children of Morta
# 4960       PS4_Children of Silentown     PS4       Children of Silentown
# 4961                   PS4_Chimparty     PS4                   Chimparty
# 4962                       PS5_qomp2     PS5                       qomp2
#
#                            Publisher         Developer  Total Shipped  \
# ...

# %%
data.groupby(["Console","Name"]).size()
# Out:
# Console  Name
# PS3      .hack: Sekai no Mukou ni + Versus    1
#          007 Legends                          1
#          007: Quantum of Solace               1
#          2 Days to Vegas                      1
#          2010 FIFA World Cup South Africa     1
#                                              ..
# PS5      Ys Memoire: The Oath in Felghana     1
#          Ys X: Nordics                        1
#          Yu-Gi-Oh! Master Duel                1
#          Zenless Zone Zero                    1
#          qomp2                                1
# Length: 4963, dtype: int64

# %%
data.groupby(["Console","Name","rating"]).size()
# Out:
# Console  Name                        rating
# PS3      007 Legends                 2.70      1
#          2014 FIFA World Cup Brazil  0.00      1
#          3D Dot Game Heroes          3.55      1
#          50 Cent: Blood on the Sand  2.11      1
#          99Vidas                     3.00      1
#                                               ..
# PS5      Wuthering Waves             4.08      1
#          XDefiant                    3.52      1
#          Yakuza: Like A Dragon       4.36      1
#          Ys X: Nordics               0.00      1
#          Zenless Zone Zero           3.35      1
# Length: 2847, dtype: int64

# %%
data.groupby(["Game","Total Sales","Publisher","Console"]).size()
# Out:
# Game                                   Total Sales  Publisher           Console
# PS3_.hack: Sekai no Mukou ni + Versus  30000.0      Namco Bandai Games  PS3        1
# PS3_007 Legends                        340000.0     Activision          PS3        1
# PS3_007: Quantum of Solace             1140000.0    Activision          PS3        1
# PS3_2 Days to Vegas                    0.0          Unknown             PS3        1
# PS3_2010 FIFA World Cup South Africa   1230000.0    EA Sports           PS3        1
#                                                                                   ..
# PS5_Ys Memoire: The Oath in Felghana   0.0          Unknown             PS5        1
# PS5_Ys X: Nordics                      0.0          Unknown             PS5        1
# PS5_Yu-Gi-Oh! Master Duel              0.0          Konami              PS5        1
# PS5_Zenless Zone Zero                  0.0          miHoYo              PS5        1
# ...

# %%
data.groupby(["genres","Console"]).size()
# Out:
# genres                                                    Console
# Action                                                    PS3        77
#                                                           PS4        99
#                                                           PS5        28
# Action, Arcade, Simulation, Indie, Massively Multiplayer  PS3         1
#                                                           PS4         1
#                                                                      ..
# Strategy, Simulation, Puzzle                              PS4         1
# Strategy, Simulation, Sports                              PS5         1
# Strategy, Sports                                          PS3         1
#                                                           PS4         2
#                                                           PS5         1
# Length: 584, dtype: int64

# %%
data.groupby(["platforms","genres"]).size()
# Out:
# platforms                                                           genres
# Android, PlayStation 3                                              Action                    1
# Nintendo 3DS, Nintendo DS, PlayStation 3, Wii                       Arcade                    1
#                                                                     Racing, Arcade            1
# Nintendo 3DS, Nintendo DS, Xbox 360, PlayStation 3, Wii             Action                    1
#                                                                     Adventure, Action         2
#                                                                                              ..
# Xbox One, iOS, Android, Nintendo DS, Xbox 360, PlayStation 3        Strategy, Simulation      1
# iOS, Android, PlayStation 3                                         Family, Arcade, Action    1
# iOS, Nintendo 3DS, Nintendo DS, Xbox 360, PlayStation 3, Wii        Adventure, Action         1
# ...

# %%
data.groupby(["Publisher","genres","rating","Console"]).size()
# Out:
# Publisher                  genres                                    rating  Console
# 10tons Ltd                 Adventure, Action, Puzzle, Casual, Indie  2.96    PS3        1
#                                                                              PS4        1
#                            Shooter, Indie, Action, RPG               4.02    PS4        1
# 11 bit studios             Indie, Adventure, Action                  4.07    PS5        1
#                            Indie, Adventure, Action, RPG             3.91    PS4        1
#                                                                                        ..
# cleaversoft                Indie                                     0.00    PS4        1
# metricminds GmbH & Co. KG  Simulation, Sports                        0.00    PS4        1
# miHoYo                     Action, RPG                               3.35    PS5        1
# ...

# %%
data.groupby(["Publisher","Total Sales"]).size()
# Out:
# Publisher                  Total Sales
# 10tons Ltd                 0.0            4
# 11 bit studios             0.0            5
#                            30000.0        1
# 17-Bit                     0.0            1
# 1C Company                 0.0            3
#                                          ..
# illuCalab                  0.0            1
# metricminds GmbH & Co. KG  0.0            1
# miHoYo                     0.0            3
# nDreams                    0.0            1
# r2 game                    0.0            2
# Length: 2045, dtype: int64

# %%
data["Console"].value_counts().plot.pie(autopct="%1.1f%%")
# Out:
# <AxesSubplot: ylabel='count'>
